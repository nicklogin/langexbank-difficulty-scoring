# %%
import pandas as pd
df1 = pd.read_excel("realec_errors_sample.xlsx", engine='openpyxl')[['id', 'Sentence']]
df2 = pd.read_excel("realec_sample_concat.xlsx", engine='openpyxl')[['Sentence','Right answer',
                                                                   'Error type','Corrected',
                                                                   'Folder','Filename']]

# %%
df = df1.merge(df2, on="Sentence")

# %%
df
# Out:
#         id                                           Sentence  \
# 0    51175   Actually, it is an old tradition of <b>distri...
# 1    36478  The graph given to us represents the informati...
# 2    67749   Moreover, they need money to feed their child...
# 3    30127   It is noticable that the figures in males <b>...
# 4     4238   Globalization creates an important basis for ...
# ..     ...                                                ...
# 836  33536  The <b>project</b> is to create an automated v...
# 837  68578   A more detailed look reveals that there are s...
# 838  80835   Firstly, I believe that space could <b>wait</...
# 839  67232   <b>Having paid</b> more attention to it we wi...
# 840  36905   It is more comfortable of course when your fr...
#
#                         Right answer             Error type  \
# 0                          spreading        lex_item_choice
# 1             the world's investment               Articles
# ...

# %%
df = df.drop_duplicates(subset=['Sentence'])

# %%
df
# Out:
#         id                                           Sentence  \
# 0    51175   Actually, it is an old tradition of <b>distri...
# 1    36478  The graph given to us represents the informati...
# 2    67749   Moreover, they need money to feed their child...
# 3    30127   It is noticable that the figures in males <b>...
# 4     4238   Globalization creates an important basis for ...
# ..     ...                                                ...
# 836  33536  The <b>project</b> is to create an automated v...
# 837  68578   A more detailed look reveals that there are s...
# 838  80835   Firstly, I believe that space could <b>wait</...
# 839  67232   <b>Having paid</b> more attention to it we wi...
# 840  36905   It is more comfortable of course when your fr...
#
#                         Right answer             Error type  \
# 0                          spreading        lex_item_choice
# 1             the world's investment               Articles
# ...

# %%
prefix_len = len('downloaded_2021_08_05_11_15_07094784/data')
df['path_in_REALEC'] = df.apply(lambda x: "https://realec.org/index.xhtml#"+x['Folder'][prefix_len:]+'/'+x['Filename']+'\n',
                                axis=1)
# Out:
# c:\users\k1l77\desktop\182e~1\term_p~1\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#         id                                           Sentence  \
# 0    51175   Actually, it is an old tradition of <b>distri...
# 1    36478  The graph given to us represents the informati...
# 2    67749   Moreover, they need money to feed their child...
# 3    30127   It is noticable that the figures in males <b>...
# 4     4238   Globalization creates an important basis for ...
# ..     ...                                                ...
# 836  33536  The <b>project</b> is to create an automated v...
# 837  68578   A more detailed look reveals that there are s...
# 838  80835   Firstly, I believe that space could <b>wait</...
# 839  67232   <b>Having paid</b> more attention to it we wi...
# 840  36905   It is more comfortable of course when your fr...
#
#                         Right answer             Error type  \
# 0                          spreading        lex_item_choice
# 1             the world's investment               Articles
# ...

# %%
df = df.drop(['Folder','Filename'], axis=1)

# %%
df
# Out:
#         id                                           Sentence  \
# 0    51175   Actually, it is an old tradition of <b>distri...
# 1    36478  The graph given to us represents the informati...
# 2    67749   Moreover, they need money to feed their child...
# 3    30127   It is noticable that the figures in males <b>...
# 4     4238   Globalization creates an important basis for ...
# ..     ...                                                ...
# 836  33536  The <b>project</b> is to create an automated v...
# 837  68578   A more detailed look reveals that there are s...
# 838  80835   Firstly, I believe that space could <b>wait</...
# 839  67232   <b>Having paid</b> more attention to it we wi...
# 840  36905   It is more comfortable of course when your fr...
#
#                         Right answer             Error type  \
# 0                          spreading        lex_item_choice
# 1             the world's investment               Articles
# ...

# %%
df.to_excel("realec_sample_concat_final.xlsx", engine="openpyxl")
